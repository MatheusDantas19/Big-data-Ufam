# %% [markdown]
# #Informações
# O projeto criado no GCP foi compartilhado para o email: alti@icomp.ufam.edu.br
#
# ---
#
# Antes de rodar os comandos do colab, o professor deve aceitar convite de compartilhamento do projeto que está no email.
#
# ---
#
# Por motivos de entregar o trabalho, eu acabei fazendo as consultas e salvando no meu proprio bucket, mas como eu compartilhei meu projeto todo ao senhor, você também tera acesso total ao bucket :)
#
# ---
# ID do projeto: matheus-dantas-3105
# Nome do cluster: matheus-dantas-3105
#
# Nome do bucket: ufam-bucket-1-matheus-dantas

# %% [markdown]
# #Login no colab
# Necessário para usar os comandos do gcp

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=TpFegCmiBhXCQQt4VuZQhnto3wMZhd&prompt=consent&access_type=offline&code_challenge=e4Mata4jtCAq484M6GGCVN79yr1-EP3EeK0km4EbIsM&code_challenge_method=S256
#
# Enter verification code: 4/1AY0e-g4WDw5UqRTWc7TSHNf1-WBkfHE3t7fYTr4GC4t00AztiXVGvPiQotk
#
# You are now logged in as [mind@icomp.ufam.edu.br].
# Your current project is [None].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %% [markdown]
# #Escrevendo o token de credenciamento

# %%
# %%writefile oi.json
# {
#   "type": "service_account",
#   "project_id": "matheus-dantas-3105",
#   "private_key_id": "6f3c1678df71f0626d20802e59964ab52715aa4b",
#   "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
#   "client_email": "cluster-matheus@matheus-dantas-3105.iam.gserviceaccount.com",
#   "client_id": "104216053268322070328",
#   "auth_uri": "https://accounts.google.com/o/oauth2/auth",
#   "token_uri": "https://oauth2.googleapis.com/token",
#   "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
#   "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/cluster-matheus%40matheus-dantas-3105.iam.gserviceaccount.com"
# }
# Out:
# Writing oi.json

# %% [markdown]
# #Importando variávies de ambiente

# %%
import os
PROJECT_ID = "matheus-dantas-3105"

# !gcloud config set project 'matheus-dantas-3105'

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = './oi.json' 
os.environ["GOOGLE_CLOUD_PROJECT"] = PROJECT_ID
os.environ["CLOUDSDK_CORE_PROJECT"] = PROJECT_ID
os.environ["CLOUDSDK_DATAPROC_REGION"] = "us-central1"
# Out:
# Updated property [core/project].

# %% [markdown]
# #Criando o bucket

# %%
BUCKET_NAME = 'ufam-bucket-1-matheus-dantas'
BUCKET_LOCATION = 'us-central1'

# %%
from googleapiclient.discovery import build
gcs_service = build('storage', 'v1')

body = {
  'name': BUCKET_NAME,
  'location': BUCKET_LOCATION,
  'storageClass': 'Standard'
}
gcs_service.buckets().insert(project=PROJECT_ID, body=body).execute()
print('Done')

# %% [markdown]
# #Enviando o arquivo da amazon-meta.txt para o bucket

# %%
# !wget https://snap.stanford.edu/data/bigdata/amazon/amazon-meta.txt.gz && gunzip amazon-meta.txt.gz

# %%
from google.cloud import storage

def upload_blob(bucket_name, source_file_name, destination_blob_name):
    """Uploads a file to the bucket."""
    # The ID of your GCS bucket
    #bucket_name = "ufam-bucket-1-matheus-dantas"
    # The path to your file to upload
    #source_file_name = "./amazon-meta.txt"
    # The ID of your GCS object
    #destination_blob_name = "storage-object-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_filename(source_file_name)

    print(
        "File {} uploaded to {}.".format(
            source_file_name, destination_blob_name
        )
    )

upload_blob(BUCKET_NAME,'./amazon-meta.txt','amazon-meta.txt')
# Out:
# File ./amazon-meta.txt uploaded to amazon-meta.txt.

# %% [markdown]
# #Criando o cluster

# %%
# !gcloud beta dataproc clusters create matheus-dantas-3105 --bucket ufam-bucket-1-matheus-dantas --enable-component-gateway \
--region us-central1 --zone us-central1-c --master-machine-type n1-standard-2 --master-boot-disk-size 32 --num-workers 5 \
--worker-machine-type n1-standard-2 --worker-boot-disk-size 32 --image-version 1.5-ubuntu18 --optional-components ANACONDA,JUPYTER \
--project matheus-dantas-3105
# Out:
# Waiting on operation [projects/matheus-dantas-3105/regions/us-central1/operations/0b9b454e-d08d-3132-b637-f0b44b461781].
#
# WARNING: For PD-Standard without local SSDs, we strongly recommend provisioning 1TB or larger to ensure consistently high I/O performance. See https://cloud.google.com/compute/docs/disks/performance for information on disk I/O performance.
# Created [https://dataproc.googleapis.com/v1beta2/projects/matheus-dantas-3105/regions/us-central1/clusters/matheus-dantas-3105] Cluster placed in zone [us-central1-c].

# %% [markdown]
# #Códigos das Questões Separadas

# %% [markdown]
# **Questão A**

# %%
# %%writefile a.py

ID_PRODUTO = '2'  ##ID DO PRODUTO

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

def transformList(word): #transformar para lista para fazer melhor manipulações
  lista = []
  for i in word:
    for j in i:
      lista.append(j)

  return lista

from pyspark import SparkConf, SparkContext, SparkFiles
import sys

conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]
text_file = sc.textFile(file_name)
lines = text_file.map(limpeza).filter(limpeza2)

#ID_PRODUTO = '2'

filtrado = lines.filter(lambda x: x['id'] == ID_PRODUTO).map(lambda x: x['reviews']).take(1)
comentarios = transformList(filtrado)

comentarios_uteis = sorted(comentarios, key = lambda i: (int(i['helpful']), int(i['rating'])), reverse=True)[0:5]
comentarios_uteis = sorted(comentarios_uteis, key = lambda i: int(i['rating']), reverse=True)

comentarios_menos_uteis = sorted(comentarios, key = lambda i: (int(i['helpful']), int(i['rating'])))[0:5]
comentarios_menos_uteis = sorted(comentarios_uteis, key = lambda i: int(i['rating']))


print("5 comentários mais úteis ordenados pela maior avaliação")
for i in range(0,5):
 print(comentarios_uteis[i])

print("\n5 comentários mais úteis ordenados pela menor avaliação")
for i in range(0,5):
 print(comentarios_menos_uteis[i])

oi = sc.parallelize(comentarios_uteis+comentarios_menos_uteis)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing a.py

# %% [markdown]
# **Questão B**

# %%
# %%writefile b.py

ID_PRODUTO = '2' ##ID DO PRODUTO

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

from pyspark import SparkConf, SparkContext, SparkFiles
import sys


conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]

text_file = sc.textFile(file_name)

lines = text_file.map(limpeza).filter(limpeza2)

filtrado = lines.filter(lambda x: x['id'] == ID_PRODUTO).map(lambda x: [x['similar'],x['salesrank']]).take(1)
result = lines.filter(lambda x: x['asin'] in filtrado[0][0] and int(x['salesrank']) < int(filtrado[0][1])).map(lambda x: [x['title'], x['salesrank']]).collect()

print("Dado um produto, listar os produtos similares com maiores vendas do que ele são:")
for i in result:
  print(i)

oi = sc.parallelize(result)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing b.py

# %% [markdown]
# **Questão C**

# %%
# %%writefile c.py

ID_PRODUTO = '2' ##ID DO PRODUTO

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

def transformList(word): #transformar para lista para fazer melhor manipulações
  lista = []
  for i in word:
    for j in i:
      lista.append(j)

  return lista

def media(anterior, valor, tamanho): #media de diaas
  vet = float(anterior) + (float(valor)-float(anterior))/float(tamanho)
  return round(vet,5)

from pyspark import SparkConf, SparkContext, SparkFiles
import sys

conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]

text_file = sc.textFile(file_name)
lines = text_file.map(limpeza).filter(limpeza2)

filtrado = lines.filter(lambda x: x['id'] == ID_PRODUTO).map(lambda x: x['reviews']).collect()
filtrado = transformList(filtrado)

vet_aux = [0]

for word in filtrado:
    vet_aux.append(media( vet_aux[len(vet_aux)-1], float(word['rating']), len(vet_aux))) 
vet_aux.pop(0)

print('A evolução diária das médias de avaliação ao longo do intervalo de tempo: ')
contador = 0

result = []

for word in filtrado:
  result.append({'data':word['data'], 'rating':word['rating'], 'average': vet_aux[contador]})
  print('data:',word['data'],' rating:',word['rating'], ' average:',end='')
  print(vet_aux[contador])
  contador+=1

oi = sc.parallelize(result)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing c.py

# %% [markdown]
# **Questão D**

# %%
# %%writefile d.py

ID_CATEGORIA = "Criminology[11005]" ##CATEGORIA

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

def oi(word):
  global ID_CATEGORIA
  vet = []
  for i in word['categories']:
    if ID_CATEGORIA == i:
      vet.append((word['title'],i,int(word['salesrank']),int(word['id'])))
  return vet


from pyspark import SparkConf, SparkContext, SparkFiles
import sys

conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]

text_file = sc.textFile(file_name)
lines = text_file.map(limpeza).filter(limpeza2)


filtrado = lines.map(oi).flatMap(lambda x: x).sortBy(lambda x: (x[1],-x[2])).take(10)

result = []

print('Categoria:',filtrado[0][1])
for i in filtrado:
  print('  ','ID',i[3],'',end='')
  print(i[0],'---- SalesRank:',i[2])

  result.append({'Id': i[3], 'Title': i[0], 'Salesrank': i[2] , 'Categoria':ID_CATEGORIA})

oi = sc.parallelize(result)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing d.py

# %% [markdown]
# **Questão** **E**

# %%
# %%writefile e.py

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

def oi(word):
  global categoria
  vet = []
  for i in word['categories']:
    if categoria == i:
      vet.append((word['title'],i,int(word['salesrank']),int(word['id'])))
  return vet

def oi2(busca): #Seleciona dados com base group == group e media in lista_media[]
  global filtrado
  contador = 0
  vet = {}
  vet['result'] = []
  for i in filtrado:
    if i[0] == busca[1] and busca[2] in i[1]:
      vet['result'].append({'title': busca[0], 'group': busca[1], 'avg':busca[2]}) 
      contador+=1

  return vet

from pyspark import SparkConf, SparkContext, SparkFiles
import sys

conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]

text_file = sc.textFile(file_name)
lines = text_file.map(limpeza).filter(limpeza2)

filtrado = lines.map(lambda x: (x['group'],x['avg_rating'])).groupByKey().map(lambda x: (x[0],sorted(list(x[1])))).map(lambda x: (x[0],x[1][-10:])).collect()

busca = lines.map(lambda x: (x['title'], x['group'], x['avg_rating']))
busca = busca.map(oi2).filter(lambda x: x['result'] != []).collect()

contador = {
    'Book':0,
    'Music':0,
    'Software':0,
    'Video':0,
    'CE':0,
    'Baby Product': 0,
    'DVD': 0,
    'Video Games':0,
    'Toy':0
}

vet = []

for i in busca:
  index = i['result'][0]['group']
  if index in list(contador.keys()) and contador[index] < 10:
    contador[index] += 1
    vet.append(i['result'][0])

vet = sorted(vet, key = lambda i: (i['group'], float(i['avg'])))
group = vet[0]['group']
print('Group:',group)

result = []
result.append("Grupo: "+group)

for i in vet:
  if i['group'] !=  group:
    group = i['group']
    print('Group:',group)
    result.append("Grupo: "+group)

  result.append(i)
  print(i)

oi = sc.parallelize(result)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing e.py

# %% [markdown]
# **Questão F**

# %%
# %%writefile f.py

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

from pyspark import SparkConf, SparkContext, SparkFiles
import sys


conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]

text_file = sc.textFile(file_name)
lines = text_file.map(limpeza).filter(limpeza2)

from operator import add

def distribui(word):
  array = []
  #return word[1]
  for i in word:
    for j in i:
      if len(j) != 1 and float(word[1]) > 0:
        array.append((j,float(word[1])))
  return array

def myCountByKey(rdd):
    return rdd.map(lambda row: (row[0], 1)).reduceByKey(add)

def getMedia(word):
  return (word[0],round(word[1][0]/word[1][1],4))

filtrado = lines.map(lambda x: (x['categories'], x['avg_rating'])).map(distribui).flatMap(lambda x: x)

ocorrencia = myCountByKey(filtrado)

media = filtrado.reduceByKey(lambda x,y: x+y).join(ocorrencia).map(getMedia).sortBy(lambda x: -x[1]).take(5)

result = []
result.append('As 5 categorias de produto com a maior média geral de ratings: ')

for i in media:
  result.append(i)
  print(i)

oi = sc.parallelize(result)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing f.py

# %% [markdown]
# **Questão G**

# %%
# %%writefile g.py

def limpeza(text): #Criando estrutura de dados para o arquivo da amazon
  text = text.split('\r\n')
  flag = 0
  vet = {}
  for index,words in enumerate(text):

    if words.startswith('Id:'):
      vet['id'] = words.split()[1].strip()

    elif words.startswith('ASIN:'):
      vet['asin'] = words.split('ASIN:')[1].strip()
        
    elif words.startswith('  title:'):
      vet['title'] = words.split('title: ')[1].strip()

    elif words.startswith('  group:'):
      vet['group'] = words.split('group:')[1].strip()

    elif words.startswith('  salesrank:'):
      vet['salesrank'] = words.split('salesrank:')[1].strip()

    elif words.startswith('  similar:'):
      if words.strip()[9] != 0:
        vet['similar'] = words.split()[2:]
      
    elif words.startswith('  categories:'):
      vet['categories'] = []

    elif words.startswith('   |'):
      categories = words.split('|')
      if len(categories) == 1:
          pass
      else:
          vet['categories'].append(categories[len(categories)-1])

    elif words.startswith('  reviews:'):
      vet['avg_rating'] =  words.split(': ')[4]
      vet['reviews'] = []

    elif words.startswith('    2') or words.startswith('    1'):
      aux = words.split()
      vet['reviews'].append({'data':aux[0], 'cliente':aux[2], 
                             'rating':aux[4], 'votes':aux[6], 'helpful':aux[8]})
            
  return vet

def limpeza2(word): #remove o id[0]
  if len(word) != 0 and len(word) > 2 :
    return word

def oi(word):
  vet = []
  for i in word['reviews']:
    vet.append(((word['group'],i['cliente']), 1))

  return vet

from pyspark import SparkConf, SparkContext, SparkFiles
import sys


conf = SparkConf().setMaster("local[*]").setAppName("Spark")
sc = SparkContext.getOrCreate(conf=conf)
sc._jsc.hadoopConfiguration().set("textinputformat.record.delimiter", "\r\n\r\n")

file_name = sys.argv[1]

text_file = sc.textFile(file_name)
lines = text_file.map(limpeza).filter(limpeza2)

filtrado = lines.filter(lambda x: x['reviews']!=[]).map(oi)

flat = filtrado.flatMap(lambda x: x).reduceByKey(lambda x,y: x+y).map(lambda x: (x[0][0],(x[0][1],x[1]))).sortBy(lambda x: (x[0],-x[1][1])).collect()

contador = 0
group = flat[0][0]

result = [] 
result.append(group)

print('Group:',group)

for i in flat:

  if i[0] != group:
    group = i[0]
    contador = 0
    result.append(group)
    print('Group:',group)

  if contador <= 10:
      print(i[1])
      result.append(i)
      contador+=1

oi = sc.parallelize(result)
oi.saveAsTextFile(sys.argv[2])
# Out:
# Writing g.py

# %% [markdown]
# #Testando o wordcount

# %% [markdown]
# ##Baixando o código wordcount

# %%
# !gsutil cp gs://la-gcp-labs-resources/data-engineer/dataproc/wordcount.py ./
# Out:
# Copying gs://la-gcp-labs-resources/data-engineer/dataproc/wordcount.py...
# / [1 files][  443.0 B/  443.0 B]
# Operation completed over 1 objects/443.0 B.

# %% [markdown]
# ##Submetendo job

# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output

# !gcloud dataproc jobs submit pyspark wordcount.py \
--cluster=matheus-dantas-3105 -- \
gs://la-gcp-labs-resources/data-engineer/dataproc/romeoandjuliet.txt  \
gs://ufam-bucket-1-matheus-dantas/output/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output/#1621183900901960...
# Removing gs://ufam-bucket-1-matheus-dantas/output/_SUCCESS#1621183916083482...
# Removing gs://ufam-bucket-1-matheus-dantas/output/part-00000#1621183914076269...
# Removing gs://ufam-bucket-1-matheus-dantas/output/part-00001#1621183914574181...
# / [4 objects]
# Operation completed over 4 objects.
# Job [941720c0a16743be93a376e8524af32d] submitted.
# Waiting for job output...
# 21/05/17 02:16:55 INFO org.spark_project.jetty.util.log: Logging initialized @4841ms
# 21/05/17 02:16:55 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:16:55 INFO org.spark_project.jetty.server.Server: Started @4984ms
# 21/05/17 02:16:55 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@8a2ab69{HTTP/1.1,[http/1.1]}{0.0.0.0:33029}
# 21/05/17 02:16:57 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at matheus-dantas-3105-m/10.128.0.47:8032
# 21/05/17 02:16:57 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at matheus-dantas-3105-m/10.128.0.47:10200
# 21/05/17 02:16:58 INFO org.apache.hadoop.conf.Configuration: resource-types.xml not found
# 21/05/17 02:16:58 INFO org.apache.hadoop.yarn.util.resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 21/05/17 02:16:58 INFO org.apache.hadoop.yarn.util.resource.ResourceUtils: Adding resource type - name = memory-mb, units = Mi, type = COUNTABLE
# 21/05/17 02:16:58 INFO org.apache.hadoop.yarn.util.resource.ResourceUtils: Adding resource type - name = vcores, units = , type = COUNTABLE
# 21/05/17 02:17:02 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1621217639651_0001
# 21/05/17 02:17:17 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# 21/05/17 02:17:33 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@8a2ab69{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [941720c0a16743be93a376e8524af32d] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/941720c0a16743be93a376e8524af32d/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/941720c0a16743be93a376e8524af32d/driveroutput
# jobUuid: 8065523b-6d76-38a6-94d9-cc7f7a7f8d8d
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs
# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output1

# !gcloud dataproc jobs submit pyspark a.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output1/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output1/#1621183967877335...
# Removing gs://ufam-bucket-1-matheus-dantas/output1/_SUCCESS#1621183971380875...
# Removing gs://ufam-bucket-1-matheus-dantas/output1/part-00000#1621183970275609...
# Removing gs://ufam-bucket-1-matheus-dantas/output1/part-00001#1621183970280439...
# / [4 objects]
# Operation completed over 4 objects.
# Job [5022609da8434c3fb72fb00ef477a73e] submitted.
# Waiting for job output...
# 21/05/17 02:17:50 INFO org.spark_project.jetty.util.log: Logging initialized @4623ms
# 21/05/17 02:17:51 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:17:51 INFO org.spark_project.jetty.server.Server: Started @4739ms
# 21/05/17 02:17:51 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@1f05398c{HTTP/1.1,[http/1.1]}{0.0.0.0:40731}
# 21/05/17 02:17:55 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# 21/05/17 02:17:57 WARN com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.gcsio.GoogleCloudStorageReadChannel: Failed read retry #1/10 for 'gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt'. Sleeping...
# java.nio.channels.ClosedByInterruptException
# 	at java.nio.channels.spi.AbstractInterruptibleChannel.end(AbstractInterruptibleChannel.java:202)
# 	at java.nio.channels.Channels$ReadableByteChannelImpl.read(Channels.java:387)
# 	at com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.gcsio.GoogleCloudStorageReadChannel.read(GoogleCloudStorageReadChannel.java:385)
# 	at com.google.cloud.hadoop.fs.gcs.GoogleHadoopFSInputStream.read(GoogleHadoopFSInputStream.java:132)
# 	at java.io.DataInputStream.read(DataInputStream.java:149)
# 	at org.apache.hadoop.mapreduce.lib.input.UncompressedSplitLineReader.fillBuffer(UncompressedSplitLineReader.java:62)
# 	at org.apache.hadoop.util.LineReader.readCustomLine(LineReader.java:306)
# 	at org.apache.hadoop.util.LineReader.readLine(LineReader.java:174)
# 	at org.apache.hadoop.mapreduce.lib.input.UncompressedSplitLineReader.readLine(UncompressedSplitLineReader.java:94)
# 	at org.apache.hadoop.mapred.LineRecordReader.next(LineRecordReader.java:255)
# 	at org.apache.hadoop.mapred.LineRecordReader.next(LineRecordReader.java:48)
# 	at org.apache.spark.rdd.HadoopRDD$$anon$1.getNext(HadoopRDD.scala:293)
# 	at org.apache.spark.rdd.HadoopRDD$$anon$1.getNext(HadoopRDD.scala:224)
# 	at org.apache.spark.util.NextIterator.hasNext(NextIterator.scala:73)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:458)
# 	at scala.collection.Iterator.foreach(Iterator.scala:941)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:941)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1429)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:224)
# 	at org.apache.spark.api.python.PythonRunner$$anon$2.writeIteratorToStream(PythonRunner.scala:561)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:346)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1945)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:196)
# 21/05/17 02:17:57 ERROR com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.gcsio.GoogleCloudStorageReadChannel: Interrupted while sleeping before retry. Giving up after 1/10 retries for 'gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt'
# 5 comentários mais úteis ordenados pela maior avaliação
# {'data': '2002-1-24', 'cliente': 'A13SG9ACZ9O5IM', 'rating': '5', 'votes': '8', 'helpful': '8'}
# {'data': '2002-5-23', 'cliente': 'A1GIL64QK68WKL', 'rating': '5', 'votes': '8', 'helpful': '8'}
# {'data': '2002-2-6', 'cliente': 'A2P6KAWXJ16234', 'rating': '4', 'votes': '16', 'helpful': '16'}
# {'data': '2002-3-23', 'cliente': 'A3GO7UV9XX14D8', 'rating': '4', 'votes': '6', 'helpful': '6'}
# {'data': '2004-2-11', 'cliente': 'A1CP26N8RHYVVO', 'rating': '1', 'votes': '13', 'helpful': '9'}
#
# 5 comentários mais úteis ordenados pela menor avaliação
# {'data': '2004-2-11', 'cliente': 'A1CP26N8RHYVVO', 'rating': '1', 'votes': '13', 'helpful': '9'}
# {'data': '2002-2-6', 'cliente': 'A2P6KAWXJ16234', 'rating': '4', 'votes': '16', 'helpful': '16'}
# {'data': '2002-3-23', 'cliente': 'A3GO7UV9XX14D8', 'rating': '4', 'votes': '6', 'helpful': '6'}
# {'data': '2002-1-24', 'cliente': 'A13SG9ACZ9O5IM', 'rating': '5', 'votes': '8', 'helpful': '8'}
# {'data': '2002-5-23', 'cliente': 'A1GIL64QK68WKL', 'rating': '5', 'votes': '8', 'helpful': '8'}
# 21/05/17 02:18:02 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@1f05398c{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [5022609da8434c3fb72fb00ef477a73e] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/5022609da8434c3fb72fb00ef477a73e/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/5022609da8434c3fb72fb00ef477a73e/driveroutput
# jobUuid: 040c514e-88fc-3079-9824-c0171d4050c3
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt
#   - gs://ufam-bucket-1-matheus-dantas/output1/
#   mainPythonFileUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/5022609da8434c3fb72fb00ef477a73e/staging/a.py
# reference:
#   jobId: 5022609da8434c3fb72fb00ef477a73e
#   projectId: matheus-dantas-3105
# status:
#   state: DONE
#   stateStartTime: '2021-05-17T02:18:03.256120Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2021-05-17T02:17:44.581382Z'
# - state: SETUP_DONE
#   stateStartTime: '2021-05-17T02:17:44.640497Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2021-05-17T02:17:44.761224Z'

# %% [markdown]
# ##Resultado da questão A

# %%
print("5 comentários mais úteis ordenados pela maior avaliação")
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output1/part-00000 

print("5 comentários mais úteis ordenados pela menor avaliação")
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output1/part-00001
# Out:
# 5 comentários mais úteis ordenados pela maior avaliação
# {'data': '2002-1-24', 'cliente': 'A13SG9ACZ9O5IM', 'rating': '5', 'votes': '8', 'helpful': '8'}
# {'data': '2002-5-23', 'cliente': 'A1GIL64QK68WKL', 'rating': '5', 'votes': '8', 'helpful': '8'}
# {'data': '2002-2-6', 'cliente': 'A2P6KAWXJ16234', 'rating': '4', 'votes': '16', 'helpful': '16'}
# {'data': '2002-3-23', 'cliente': 'A3GO7UV9XX14D8', 'rating': '4', 'votes': '6', 'helpful': '6'}
# {'data': '2004-2-11', 'cliente': 'A1CP26N8RHYVVO', 'rating': '1', 'votes': '13', 'helpful': '9'}
# 5 comentários mais úteis ordenados pela menor avaliação
# {'data': '2004-2-11', 'cliente': 'A1CP26N8RHYVVO', 'rating': '1', 'votes': '13', 'helpful': '9'}
# {'data': '2002-2-6', 'cliente': 'A2P6KAWXJ16234', 'rating': '4', 'votes': '16', 'helpful': '16'}
# {'data': '2002-3-23', 'cliente': 'A3GO7UV9XX14D8', 'rating': '4', 'votes': '6', 'helpful': '6'}
# {'data': '2002-1-24', 'cliente': 'A13SG9ACZ9O5IM', 'rating': '5', 'votes': '8', 'helpful': '8'}
# {'data': '2002-5-23', 'cliente': 'A1GIL64QK68WKL', 'rating': '5', 'votes': '8', 'helpful': '8'}

# %% [markdown]
# ##Submentendo Job Questão B

# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output2

# !gcloud dataproc jobs submit pyspark b.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output2/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output2/#1621184030379126...
# Removing gs://ufam-bucket-1-matheus-dantas/output2/_SUCCESS#1621184034171952...
# Removing gs://ufam-bucket-1-matheus-dantas/output2/part-00000#1621184032898652...
# Removing gs://ufam-bucket-1-matheus-dantas/output2/part-00001#1621184033079956...
# / [4 objects]
# Operation completed over 4 objects.
# Job [ca85b733fbc345838a01680a68bce86b] submitted.
# Waiting for job output...
# 21/05/17 02:18:16 INFO org.spark_project.jetty.util.log: Logging initialized @4202ms
# 21/05/17 02:18:16 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:18:16 INFO org.spark_project.jetty.server.Server: Started @4330ms
# 21/05/17 02:18:16 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@651f9c6b{HTTP/1.1,[http/1.1]}{0.0.0.0:38237}
# 21/05/17 02:18:20 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# 21/05/17 02:18:22 WARN com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.gcsio.GoogleCloudStorageReadChannel: Failed read retry #1/10 for 'gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt'. Sleeping...
# java.nio.channels.ClosedByInterruptException
# 	at java.nio.channels.spi.AbstractInterruptibleChannel.end(AbstractInterruptibleChannel.java:202)
# 	at java.nio.channels.Channels$ReadableByteChannelImpl.read(Channels.java:387)
# 	at com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.gcsio.GoogleCloudStorageReadChannel.read(GoogleCloudStorageReadChannel.java:385)
# 	at com.google.cloud.hadoop.fs.gcs.GoogleHadoopFSInputStream.read(GoogleHadoopFSInputStream.java:132)
# 	at java.io.DataInputStream.read(DataInputStream.java:149)
# 	at org.apache.hadoop.mapreduce.lib.input.UncompressedSplitLineReader.fillBuffer(UncompressedSplitLineReader.java:62)
# 	at org.apache.hadoop.util.LineReader.readCustomLine(LineReader.java:306)
# 	at org.apache.hadoop.util.LineReader.readLine(LineReader.java:174)
# 	at org.apache.hadoop.mapreduce.lib.input.UncompressedSplitLineReader.readLine(UncompressedSplitLineReader.java:94)
# 	at org.apache.hadoop.mapred.LineRecordReader.next(LineRecordReader.java:255)
# 	at org.apache.hadoop.mapred.LineRecordReader.next(LineRecordReader.java:48)
# 	at org.apache.spark.rdd.HadoopRDD$$anon$1.getNext(HadoopRDD.scala:293)
# 	at org.apache.spark.rdd.HadoopRDD$$anon$1.getNext(HadoopRDD.scala:224)
# 	at org.apache.spark.util.NextIterator.hasNext(NextIterator.scala:73)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:458)
# 	at scala.collection.Iterator.foreach(Iterator.scala:941)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:941)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1429)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:224)
# 	at org.apache.spark.api.python.PythonRunner$$anon$2.writeIteratorToStream(PythonRunner.scala:561)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:346)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1945)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:196)
# 21/05/17 02:18:22 ERROR com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.gcsio.GoogleCloudStorageReadChannel: Interrupted while sleeping before retry. Giving up after 1/10 retries for 'gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt'
# Dado um produto, listar os produtos similares com maiores vendas do que ele são:
# ['Yule: A Celebration of Light and Warmth', '103012']
# ['Midsummer: Magical Celebrations of the Summer Solstice', '159277']
# ['Lammas', '58836']
# 21/05/17 02:19:04 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@651f9c6b{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [ca85b733fbc345838a01680a68bce86b] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/ca85b733fbc345838a01680a68bce86b/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/ca85b733fbc345838a01680a68bce86b/driveroutput
# jobUuid: 2129d35d-9d45-3742-aa8a-30b280c8c66f
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt
#   - gs://ufam-bucket-1-matheus-dantas/output2/
#   mainPythonFileUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/ca85b733fbc345838a01680a68bce86b/staging/b.py
# reference:
#   jobId: ca85b733fbc345838a01680a68bce86b
#   projectId: matheus-dantas-3105
# status:
#   state: DONE
#   stateStartTime: '2021-05-17T02:19:05.382613Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2021-05-17T02:18:10.159562Z'
# - state: SETUP_DONE
#   stateStartTime: '2021-05-17T02:18:10.195033Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2021-05-17T02:18:10.480718Z'

# %% [markdown]
# ##Resultado da questão B

# %%
print("Dado um produto, listar os produtos similares com maiores vendas do que ele:")
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output2/part*
# Out:
# Dado um produto, listar os produtos similares com maiores vendas do que ele:
# ['Yule: A Celebration of Light and Warmth', '103012']
# ['Midsummer: Magical Celebrations of the Summer Solstice', '159277']
# ['Lammas', '58836']

# %% [markdown]
# ##Submetendo Job da Questão C

# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output3

# !gcloud dataproc jobs submit pyspark c.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output3/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output3/#1621184089199743...
# Removing gs://ufam-bucket-1-matheus-dantas/output3/_SUCCESS#1621184092337046...
# Removing gs://ufam-bucket-1-matheus-dantas/output3/part-00000#1621184091236060...
# Removing gs://ufam-bucket-1-matheus-dantas/output3/part-00001#1621184091095672...
# / [4 objects]
# Operation completed over 4 objects.
# Job [3935f92e2ea048d6b31cec186e5462e5] submitted.
# Waiting for job output...
# 21/05/17 02:19:17 INFO org.spark_project.jetty.util.log: Logging initialized @4218ms
# 21/05/17 02:19:17 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:19:17 INFO org.spark_project.jetty.server.Server: Started @4333ms
# 21/05/17 02:19:17 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@651f9c6b{HTTP/1.1,[http/1.1]}{0.0.0.0:35769}
# 21/05/17 02:19:21 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# A evolução diária das médias de avaliação ao longo do intervalo de tempo:
# data: 2001-12-16  rating: 5  average:5.0
# data: 2002-1-7  rating: 4  average:4.5
# data: 2002-1-24  rating: 5  average:4.66667
# data: 2002-1-28  rating: 5  average:4.75
# data: 2002-2-6  rating: 4  average:4.6
# data: 2002-2-14  rating: 4  average:4.5
# data: 2002-3-23  rating: 4  average:4.42857
# data: 2002-5-23  rating: 5  average:4.5
# data: 2003-2-25  rating: 5  average:4.55556
# data: 2003-11-25  rating: 5  average:4.6
# data: 2004-2-11  rating: 1  average:4.27273
# data: 2005-2-7  rating: 5  average:4.33334
# 21/05/17 02:20:03 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@651f9c6b{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [3935f92e2ea048d6b31cec186e5462e5] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/3935f92e2ea048d6b31cec186e5462e5/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/3935f92e2ea048d6b31cec186e5462e5/driveroutput
# jobUuid: 015b31ec-1f71-399c-8d99-df2ecf59aa41
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt
#   - gs://ufam-bucket-1-matheus-dantas/output3/
#   mainPythonFileUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/3935f92e2ea048d6b31cec186e5462e5/staging/c.py
# reference:
#   jobId: 3935f92e2ea048d6b31cec186e5462e5
#   projectId: matheus-dantas-3105
# status:
#   state: DONE
#   stateStartTime: '2021-05-17T02:20:04.364295Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2021-05-17T02:19:11.235763Z'
# - state: SETUP_DONE
#   stateStartTime: '2021-05-17T02:19:11.268977Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2021-05-17T02:19:11.528252Z'

# %% [markdown]
# ##Resultado da questão C

# %%
print('A evolução diária das médias de avaliação ao longo do intervalo de tempo: ')
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output3/part*
# Out:
# A evolução diária das médias de avaliação ao longo do intervalo de tempo:
# {'data': '2001-12-16', 'rating': '5', 'average': 5.0}
# {'data': '2002-1-7', 'rating': '4', 'average': 4.5}
# {'data': '2002-1-24', 'rating': '5', 'average': 4.66667}
# {'data': '2002-1-28', 'rating': '5', 'average': 4.75}
# {'data': '2002-2-6', 'rating': '4', 'average': 4.6}
# {'data': '2002-2-14', 'rating': '4', 'average': 4.5}
# {'data': '2002-3-23', 'rating': '4', 'average': 4.42857}
# {'data': '2002-5-23', 'rating': '5', 'average': 4.5}
# {'data': '2003-2-25', 'rating': '5', 'average': 4.55556}
# {'data': '2003-11-25', 'rating': '5', 'average': 4.6}
# {'data': '2004-2-11', 'rating': '1', 'average': 4.27273}
# {'data': '2005-2-7', 'rating': '5', 'average': 4.33334}

# %% [markdown]
# ##Submetendo Job da questão D

# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output4

# !gcloud dataproc jobs submit pyspark d.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output4/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output4/#1621185413680568...
# Removing gs://ufam-bucket-1-matheus-dantas/output4/_SUCCESS#1621185416736283...
# Removing gs://ufam-bucket-1-matheus-dantas/output4/part-00000#1621185415753212...
# Removing gs://ufam-bucket-1-matheus-dantas/output4/part-00001#1621185415730029...
# / [4 objects]
# Operation completed over 4 objects.
# Job [75732fb1465b400699c00dafa9c5eced] submitted.
# Waiting for job output...
# 21/05/17 02:20:15 INFO org.spark_project.jetty.util.log: Logging initialized @4290ms
# 21/05/17 02:20:15 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:20:15 INFO org.spark_project.jetty.server.Server: Started @4425ms
# 21/05/17 02:20:15 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@4a03f277{HTTP/1.1,[http/1.1]}{0.0.0.0:43041}
# 21/05/17 02:20:20 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output5

# !gcloud dataproc jobs submit pyspark e.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output5/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output5/#1621184291078023...
# Removing gs://ufam-bucket-1-matheus-dantas/output5/_SUCCESS#1621184294300943...
# Removing gs://ufam-bucket-1-matheus-dantas/output5/part-00000#1621184293311000...
# Removing gs://ufam-bucket-1-matheus-dantas/output5/part-00001#1621184293091428...
# / [4 objects]
# Operation completed over 4 objects.
# Job [18d006c58b7c4230a9b2f2f2df6316df] submitted.
# Waiting for job output...
# 21/05/17 02:22:30 INFO org.spark_project.jetty.util.log: Logging initialized @4056ms
# 21/05/17 02:22:30 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:22:30 INFO org.spark_project.jetty.server.Server: Started @4191ms
# 21/05/17 02:22:30 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@64de0169{HTTP/1.1,[http/1.1]}{0.0.0.0:35961}
# 21/05/17 02:22:34 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# Group: Baby Product
# {'title': "Baby'S Record Keeper And Memory Box", 'group': 'Baby Product', 'avg': '4.5'}
# Group: Book
# {'title': 'Patterns of Preaching: A Sermon Sampler', 'group': 'Book', 'avg': '5'}
# {'title': 'World War II Allied Fighter Planes Trading Cards', 'group': 'Book', 'avg': '5'}
# {'title': 'Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life', 'group': 'Book', 'avg': '5'}
# {'title': 'Computed Tomography : Fundamentals, System Technology, Image Quality, Applications', 'group': 'Book', 'avg': '5'}
# {'title': 'Backroad Buffets & Country Cafes: A Southern Guide to Meat-And-Threes & Down-Home Dining', 'group': 'Book', 'avg': '5'}
# {'title': 'Double Jeopardy (T*Witches, 6)', 'group': 'Book', 'avg': '5'}
# {'title': 'Renovations: A Father and Son Rebuild a House and Rediscover Each Other', 'group': 'Book', 'avg': '5'}
# {'title': 'How to Kill a Monster (Goosebumps)', 'group': 'Book', 'avg': '5'}
# {'title': 'Baby Boomer Retirement: 65 Simple Ways to Protect Your Future', 'group': 'Book', 'avg': '5'}
# {'title': 'Betsy & Tacy Go over the Big Hill (Betsy and Tacy Books)', 'group': 'Book', 'avg': '5'}
# Group: CE
# {'title': 'SPELLING CORRECTOR', 'group': 'CE', 'avg': '0'}
# {'title': 'Hal Leonard Beginning Guitar 1, Instructional Video, 30 Minutes', 'group': 'CE', 'avg': '0'}
# {'title': 'FRANKLIN COMP. KJB-1440 Electronic Holy Bible (King James Version)', 'group': 'CE', 'avg': '3'}
# {'title': 'Hal Leonard Beginning Bass Guitar 1, Instructional Video, 30 Minutes', 'group': 'CE', 'avg': '4'}
# Group: DVD
# {'title': "Avengers '67 - Set 1, Vols. 1 & 2", 'group': 'DVD', 'avg': '5'}
# {'title': 'DC Talk: Free at Last - The Movie', 'group': 'DVD', 'avg': '5'}
# {'title': 'Anne-Sophie Mutter - A Life with Beethoven', 'group': 'DVD', 'avg': '5'}
# {'title': 'Cowboy Bebop - Session 2', 'group': 'DVD', 'avg': '5'}
# {'title': 'The Adventures of Sherlock Holmes,  Vol. 4 (The Greek Interpreter / The Norwood Builder)', 'group': 'DVD', 'avg': '5'}
# {'title': 'Richard Strauss - Concerto for Horn', 'group': 'DVD', 'avg': '5'}
# {'title': 'I Love Lucy - Season One (Vol. 3)', 'group': 'DVD', 'avg': '5'}
# {'title': 'Weird Al Yankovic - Live', 'group': 'DVD', 'avg': '5'}
# {'title': 'The Blonde', 'group': 'DVD', 'avg': '5'}
# {'title': 'Business is Business', 'group': 'DVD', 'avg': '5'}
# Group: Music
# {'title': 'Sol to Soul', 'group': 'Music', 'avg': '5'}
# {'title': 'Still Life', 'group': 'Music', 'avg': '5'}
# {'title': 'What\'s on Your Mind (Pure Energy) [Tommy Boy CD5/12")', 'group': 'Music', 'avg': '5'}
# {'title': 'Lush Mechanique', 'group': 'Music', 'avg': '5'}
# {'title': 'Johnny Bush - 14 Greatest Hits', 'group': 'Music', 'avg': '5'}
# {'title': 'One More Night', 'group': 'Music', 'avg': '5'}
# {'title': 'Riddle', 'group': 'Music', 'avg': '5'}
# {'title': "Singin' Some Soul", 'group': 'Music', 'avg': '5'}
# {'title': 'Roadside (2001 Off-Broadway Cast)', 'group': 'Music', 'avg': '5'}
# {'title': 'Motown Party', 'group': 'Music', 'avg': '5'}
# Group: Software
# {'title': "Zondervan Bible Study Library: Leader's Edition 5.0", 'group': 'Software', 'avg': '3.5'}
# {'title': 'WINDOWS NT SERVER V4.0 RESOURCE', 'group': 'Software', 'avg': '4'}
# {'title': 'RINGDISC Wagner: The Ring Disc', 'group': 'Software', 'avg': '5'}
# {'title': 'ClickArt Christian Publishing Suite 3', 'group': 'Software', 'avg': '5'}
# {'title': 'Just Enough Vocals The Learning Co', 'group': 'Software', 'avg': '5'}
# Group: Toy
# {'title': 'R- Photostory Senior', 'group': 'Toy', 'avg': '0'}
# {'title': 'The Songs of Britney Spears & Christina Aguilera', 'group': 'Toy', 'avg': '3'}
# {'title': 'Party Tyme Karaoke CD: V2 Super Hits', 'group': 'Toy', 'avg': '3.5'}
# {'title': 'Party Tyme Karaoke CD Oldies', 'group': 'Toy', 'avg': '4'}
# {'title': 'Party Tyme Karaoke CD Kids Songs', 'group': 'Toy', 'avg': '5'}
# {'title': 'IlluStory Book Kit', 'group': 'Toy', 'avg': '5'}
# {'title': 'Photostory Junior Book Kit', 'group': 'Toy', 'avg': '5'}
# {'title': 'Wizard Card Game Deluxe', 'group': 'Toy', 'avg': '5'}
# Group: Video
# {'title': 'Jonny Quest - Bandit in Adventures Best Friend', 'group': 'Video', 'avg': '5'}
# {'title': 'Barney: Sing and Dance with Barney', 'group': 'Video', 'avg': '5'}
# {'title': 'Bob Newhart - Button Down Concert - Off the Record', 'group': 'Video', 'avg': '5'}
# {'title': 'The Glass Menagerie', 'group': 'Video', 'avg': '5'}
# {'title': "National Geographic's Land of the Anaconda", 'group': 'Video', 'avg': '5'}
# {'title': 'Wow Gospel 1999', 'group': 'Video', 'avg': '5'}
# {'title': "It's Arbor Day, Charlie Brown", 'group': 'Video', 'avg': '5'}
# {'title': 'The Sweetest Gift', 'group': 'Video', 'avg': '5'}
# {'title': 'The Best of The Simpsons, Boxed Set 3', 'group': 'Video', 'avg': '5'}
# {'title': "Dixie Carter's Unworkout", 'group': 'Video', 'avg': '5'}
# Group: Video Games
# {'title': 'PRIMA PUBLISHING Dark Cloud 2 Official Strategy Guide', 'group': 'Video Games', 'avg': '2.5'}
# 21/05/17 02:23:57 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@64de0169{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [18d006c58b7c4230a9b2f2f2df6316df] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/18d006c58b7c4230a9b2f2f2df6316df/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/18d006c58b7c4230a9b2f2f2df6316df/driveroutput
# jobUuid: 49002935-b71d-38a1-9828-017210ec3f9e
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt
#   - gs://ufam-bucket-1-matheus-dantas/output5/
#   mainPythonFileUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/18d006c58b7c4230a9b2f2f2df6316df/staging/e.py
# reference:
#   jobId: 18d006c58b7c4230a9b2f2f2df6316df
#   projectId: matheus-dantas-3105
# status:
#   state: DONE
#   stateStartTime: '2021-05-17T02:23:58.995374Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2021-05-17T02:22:24.516104Z'
# - state: SETUP_DONE
#   stateStartTime: '2021-05-17T02:22:24.551027Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2021-05-17T02:22:24.730584Z'

# %% [markdown]
# ##Resultado da questão E

# %%
print('Os 10 produtos com a maior média de ratings por grupo (Group) de produtos: ')
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output5/part*
# Out:
# Os 10 produtos com a maior média de ratings por grupo (Group) de produtos:
# Grupo: Baby Product
# {'title': "Baby'S Record Keeper And Memory Box", 'group': 'Baby Product', 'avg': '4.5'}
# Grupo: Book
# {'title': 'Patterns of Preaching: A Sermon Sampler', 'group': 'Book', 'avg': '5'}
# {'title': 'World War II Allied Fighter Planes Trading Cards', 'group': 'Book', 'avg': '5'}
# {'title': 'Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life', 'group': 'Book', 'avg': '5'}
# {'title': 'Computed Tomography : Fundamentals, System Technology, Image Quality, Applications', 'group': 'Book', 'avg': '5'}
# {'title': 'Backroad Buffets & Country Cafes: A Southern Guide to Meat-And-Threes & Down-Home Dining', 'group': 'Book', 'avg': '5'}
# {'title': 'Double Jeopardy (T*Witches, 6)', 'group': 'Book', 'avg': '5'}
# {'title': 'Renovations: A Father and Son Rebuild a House and Rediscover Each Other', 'group': 'Book', 'avg': '5'}
# {'title': 'How to Kill a Monster (Goosebumps)', 'group': 'Book', 'avg': '5'}
# {'title': 'Baby Boomer Retirement: 65 Simple Ways to Protect Your Future', 'group': 'Book', 'avg': '5'}
# {'title': 'Betsy & Tacy Go over the Big Hill (Betsy and Tacy Books)', 'group': 'Book', 'avg': '5'}
# Grupo: CE
# {'title': 'SPELLING CORRECTOR', 'group': 'CE', 'avg': '0'}
# {'title': 'Hal Leonard Beginning Guitar 1, Instructional Video, 30 Minutes', 'group': 'CE', 'avg': '0'}
# {'title': 'FRANKLIN COMP. KJB-1440 Electronic Holy Bible (King James Version)', 'group': 'CE', 'avg': '3'}
# {'title': 'Hal Leonard Beginning Bass Guitar 1, Instructional Video, 30 Minutes', 'group': 'CE', 'avg': '4'}
# Grupo: DVD
# {'title': "Avengers '67 - Set 1, Vols. 1 & 2", 'group': 'DVD', 'avg': '5'}
# {'title': 'DC Talk: Free at Last - The Movie', 'group': 'DVD', 'avg': '5'}
# {'title': 'Anne-Sophie Mutter - A Life with Beethoven', 'group': 'DVD', 'avg': '5'}
# {'title': 'Cowboy Bebop - Session 2', 'group': 'DVD', 'avg': '5'}
# {'title': 'The Adventures of Sherlock Holmes,  Vol. 4 (The Greek Interpreter / The Norwood Builder)', 'group': 'DVD', 'avg': '5'}
# {'title': 'Richard Strauss - Concerto for Horn', 'group': 'DVD', 'avg': '5'}
# {'title': 'I Love Lucy - Season One (Vol. 3)', 'group': 'DVD', 'avg': '5'}
# {'title': 'Weird Al Yankovic - Live', 'group': 'DVD', 'avg': '5'}
# {'title': 'The Blonde', 'group': 'DVD', 'avg': '5'}
# {'title': 'Business is Business', 'group': 'DVD', 'avg': '5'}
# Grupo: Music
# {'title': 'Sol to Soul', 'group': 'Music', 'avg': '5'}
# {'title': 'Still Life', 'group': 'Music', 'avg': '5'}
# {'title': 'What\'s on Your Mind (Pure Energy) [Tommy Boy CD5/12")', 'group': 'Music', 'avg': '5'}
# {'title': 'Lush Mechanique', 'group': 'Music', 'avg': '5'}
# {'title': 'Johnny Bush - 14 Greatest Hits', 'group': 'Music', 'avg': '5'}
# {'title': 'One More Night', 'group': 'Music', 'avg': '5'}
# {'title': 'Riddle', 'group': 'Music', 'avg': '5'}
# {'title': "Singin' Some Soul", 'group': 'Music', 'avg': '5'}
# {'title': 'Roadside (2001 Off-Broadway Cast)', 'group': 'Music', 'avg': '5'}
# {'title': 'Motown Party', 'group': 'Music', 'avg': '5'}
# Grupo: Software
# {'title': "Zondervan Bible Study Library: Leader's Edition 5.0", 'group': 'Software', 'avg': '3.5'}
# {'title': 'WINDOWS NT SERVER V4.0 RESOURCE', 'group': 'Software', 'avg': '4'}
# {'title': 'RINGDISC Wagner: The Ring Disc', 'group': 'Software', 'avg': '5'}
# {'title': 'ClickArt Christian Publishing Suite 3', 'group': 'Software', 'avg': '5'}
# {'title': 'Just Enough Vocals The Learning Co', 'group': 'Software', 'avg': '5'}
# Grupo: Toy
# {'title': 'R- Photostory Senior', 'group': 'Toy', 'avg': '0'}
# {'title': 'The Songs of Britney Spears & Christina Aguilera', 'group': 'Toy', 'avg': '3'}
# {'title': 'Party Tyme Karaoke CD: V2 Super Hits', 'group': 'Toy', 'avg': '3.5'}
# {'title': 'Party Tyme Karaoke CD Oldies', 'group': 'Toy', 'avg': '4'}
# {'title': 'Party Tyme Karaoke CD Kids Songs', 'group': 'Toy', 'avg': '5'}
# {'title': 'IlluStory Book Kit', 'group': 'Toy', 'avg': '5'}
# {'title': 'Photostory Junior Book Kit', 'group': 'Toy', 'avg': '5'}
# {'title': 'Wizard Card Game Deluxe', 'group': 'Toy', 'avg': '5'}
# Grupo: Video
# {'title': 'Jonny Quest - Bandit in Adventures Best Friend', 'group': 'Video', 'avg': '5'}
# {'title': 'Barney: Sing and Dance with Barney', 'group': 'Video', 'avg': '5'}
# {'title': 'Bob Newhart - Button Down Concert - Off the Record', 'group': 'Video', 'avg': '5'}
# {'title': 'The Glass Menagerie', 'group': 'Video', 'avg': '5'}
# {'title': "National Geographic's Land of the Anaconda", 'group': 'Video', 'avg': '5'}
# {'title': 'Wow Gospel 1999', 'group': 'Video', 'avg': '5'}
# {'title': "It's Arbor Day, Charlie Brown", 'group': 'Video', 'avg': '5'}
# {'title': 'The Sweetest Gift', 'group': 'Video', 'avg': '5'}
# {'title': 'The Best of The Simpsons, Boxed Set 3', 'group': 'Video', 'avg': '5'}
# {'title': "Dixie Carter's Unworkout", 'group': 'Video', 'avg': '5'}
# Grupo: Video Games
# {'title': 'PRIMA PUBLISHING Dark Cloud 2 Official Strategy Guide', 'group': 'Video Games', 'avg': '2.5'}

# %% [markdown]
# ##Submetendo Job da Questão F

# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output6

# !gcloud dataproc jobs submit pyspark f.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output6/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output6/#1621184401210629...
# Removing gs://ufam-bucket-1-matheus-dantas/output6/_SUCCESS#1621184404759997...
# Removing gs://ufam-bucket-1-matheus-dantas/output6/part-00000#1621184403687888...
# Removing gs://ufam-bucket-1-matheus-dantas/output6/part-00001#1621184403517276...
# / [4 objects]
# Operation completed over 4 objects.
# Job [9045808067e3426eb8bf70e884a0ead3] submitted.
# Waiting for job output...
# 21/05/17 02:24:10 INFO org.spark_project.jetty.util.log: Logging initialized @4305ms
# 21/05/17 02:24:10 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:24:10 INFO org.spark_project.jetty.server.Server: Started @4442ms
# 21/05/17 02:24:10 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@64de0169{HTTP/1.1,[http/1.1]}{0.0.0.0:39649}
# 21/05/17 02:24:15 INFO org.apache.hadoop.mapred.FileInputFormat: Total input files to process : 1
# ('Mitchell, Leona[153782]', 5.0)
# ('Orchestra of the Age of Enlightenment[55673]', 5.0)
# ('Antiques[2493]', 5.0)
# ('General[2521]', 5.0)
# ('Frog and Toad[3309]', 5.0)
# 21/05/17 02:25:48 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@64de0169{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [9045808067e3426eb8bf70e884a0ead3] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/9045808067e3426eb8bf70e884a0ead3/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/9045808067e3426eb8bf70e884a0ead3/driveroutput
# jobUuid: 1ac8b121-4ca6-3fda-a261-b700e92675b1
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt
#   - gs://ufam-bucket-1-matheus-dantas/output6/
#   mainPythonFileUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/9045808067e3426eb8bf70e884a0ead3/staging/f.py
# reference:
#   jobId: 9045808067e3426eb8bf70e884a0ead3
#   projectId: matheus-dantas-3105
# status:
#   state: DONE
#   stateStartTime: '2021-05-17T02:25:49.753264Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2021-05-17T02:24:04.790702Z'
# - state: SETUP_DONE
#   stateStartTime: '2021-05-17T02:24:04.821982Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2021-05-17T02:24:04.936451Z'

# %% [markdown]
# ##Resultado da Questão F

# %%
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output6/part*
# Out:
# As 5 categorias de produto com a maior média geral de ratings:
# ('Mitchell, Leona[153782]', 5.0)
# ('Orchestra of the Age of Enlightenment[55673]', 5.0)
# ('Antiques[2493]', 5.0)
# ('General[2521]', 5.0)
# ('Frog and Toad[3309]', 5.0)

# %% [markdown]
# ##Submetendo Job da Questão G

# %%
# !gsutil rm -rf gs://ufam-bucket-1-matheus-dantas/output7

# !gcloud dataproc jobs submit pyspark g.py \
--cluster=matheus-dantas-3105 --bucket=ufam-bucket-1-matheus-dantas -- \
gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt  \
gs://ufam-bucket-1-matheus-dantas/output7/
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/output7/#1621184539699645...
# Removing gs://ufam-bucket-1-matheus-dantas/output7/_SUCCESS#1621184543228203...
# Removing gs://ufam-bucket-1-matheus-dantas/output7/part-00000#1621184541808976...
# Removing gs://ufam-bucket-1-matheus-dantas/output7/part-00001#1621184542088358...
# / [4 objects]
# Operation completed over 4 objects.
# Job [b7881b5138724a8a87fe72097a37036c] submitted.
# Waiting for job output...
# 21/05/17 02:26:01 INFO org.spark_project.jetty.util.log: Logging initialized @4320ms
# 21/05/17 02:26:01 INFO org.spark_project.jetty.server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
# 21/05/17 02:26:01 INFO org.spark_project.jetty.server.Server: Started @4452ms
# 21/05/17 02:26:01 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@4a03f277{HTTP/1.1,[http/1.1]}{0.0.0.0:44355}
# ('A3UN6WX5RRO2AG', 1)
# Group: Video
# ('ATVPDKIKX0DER', 72581)
# ('A3UN6WX5RRO2AG', 15814)
# ('A2NJO6YE954DBH', 1775)
# ('AU8552YCOO5QX', 1205)
# ('A3P1A63Q8L32C5', 737)
# ('A20EEWWSFMZ1PN', 720)
# ('A16CZRQL23NOIW', 668)
# ('A3LZGLA88K0LA0', 614)
# ('A2QRB6L1MCJ53G', 606)
# ('A152C8GYY25HAH', 583)
# ('A9Q28YTLYREO7', 579)
# Group: Video Games
# ('A3C811U31YG6FS', 1)
# ('A226EDS7WDF7S1', 1)
# ('A1M4NJYP0WNL8Q', 1)
# 21/05/17 02:28:10 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@4a03f277{HTTP/1.1,[http/1.1]}{0.0.0.0:0}
# Job [b7881b5138724a8a87fe72097a37036c] finished successfully.
# done: true
# driverControlFilesUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/b7881b5138724a8a87fe72097a37036c/
# driverOutputResourceUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/b7881b5138724a8a87fe72097a37036c/driveroutput
# jobUuid: ab68471d-f952-3171-8818-eb9cf6f92a2b
# placement:
#   clusterName: matheus-dantas-3105
#   clusterUuid: 202243a9-e77a-4c97-b076-e62fb8bfad6b
# pysparkJob:
#   args:
#   - gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt
#   - gs://ufam-bucket-1-matheus-dantas/output7/
#   mainPythonFileUri: gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/b7881b5138724a8a87fe72097a37036c/staging/g.py
# reference:
#   jobId: b7881b5138724a8a87fe72097a37036c
#   projectId: matheus-dantas-3105
# status:
#   state: DONE
#   stateStartTime: '2021-05-17T02:28:11.310852Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2021-05-17T02:25:55.637627Z'
# - state: SETUP_DONE
#   stateStartTime: '2021-05-17T02:25:55.695837Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2021-05-17T02:25:55.949422Z'

# %% [markdown]
# ##Resultado da questão G

# %%
print('Lista dos 10 clientes que mais fizeram comentários por grupo (Group) de produto')
# !gsutil cat gs://ufam-bucket-1-matheus-dantas/output7/part*
# Out:
# Lista dos 10 clientes que mais fizeram comentários por grupo (Group) de produto
# Baby Product
# ('Baby Product', ('A2LAH8VX720175', 1))
# ('Baby Product', ('AI9SB5VKUFXDC', 1))
# ('Baby Product', ('A37TFIP0OMKGMW', 1))
# Book
# ('Book', ('ATVPDKIKX0DER', 643185))
# ('Book', ('A3UN6WX5RRO2AG', 154531))
# ('Book', ('A14OJS0VWMOSWO', 9589))
# ('Book', ('AFVQZQ8PW0L', 5441))
# ('Book', ('A1K1JW1C5CUSUZ', 3562))
# ('Book', ('A2NJO6YE954DBH', 2055))
# ('Book', ('A3QVAKVRAH657N', 1651))
# ('Book', ('A1NATT3PN24QWY', 1535))
# ('Book', ('A1D2C0WDCSHUWZ', 1508))
# ('Book', ('A2ODBHT4URXVXQ', 1469))
# ('Book', ('A3SN9EF7GTNEU2', 1387))
# CE
# ('CE', ('A1SFX3CR838F36', 1))
# ('CE', ('A1328SYT22GA4U', 1))
# ('CE', ('A13JU90C7AU3RT', 1))
# ('CE', ('A1J62O1S6QTHZJ', 1))
# ('CE', ('A2IX9TMXDBUCYV', 1))
# DVD
# ('DVD', ('ATVPDKIKX0DER', 63148))
# ('DVD', ('A3UN6WX5RRO2AG', 15549))
# ('DVD', ('A2NJO6YE954DBH', 1366))
# ('DVD', ('AU8552YCOO5QX', 1213))
# ('DVD', ('A3P1A63Q8L32C5', 859))
# ('DVD', ('A3LZGLA88K0LA0', 856))
# ('DVD', ('A82LIVYSX6WZ9', 683))
# ('DVD', ('A152C8GYY25HAH', 675))
# ('DVD', ('A16CZRQL23NOIW', 651))
# ('DVD', ('A1CZICCYP2M5PX', 650))
# ('DVD', ('AJKWF4W7QD4NS', 612))
# Music
# ('Music', ('ATVPDKIKX0DER', 166149))
# ('Music', ('A3UN6WX5RRO2AG', 15875))
# ('Music', ('A9Q28YTLYREO7', 2760))
# ('Music', ('A2U49LUUY4IKQQ', 1258))
# ('Music', ('A1GN8UJIZLCA59', 1154))
# ('Music', ('A2NJO6YE954DBH', 1128))
# ('Music', ('A1J5KCZC8CMW9I', 1031))
# ('Music', ('A3MOF5KF93Q6WE', 989))
# ('Music', ('AXFI7TAWD6H6X', 814))
# ('Music', ('A38U2M9OAEJAXJ', 780))
# ('Music', ('A2EENLV6OQ3DYM', 776))
# Software
# ('Software', ('A23DFB8IUTIZM0', 1))
# ('Software', ('A36NHJPD24UMGJ', 1))
# ('Software', ('A39UZ9VVRJW4P8', 1))
# ('Software', ('A3D5ICIQ8STPCH', 1))
# ('Software', ('A1XQB8IU7S8WEU', 1))
# ('Software', ('A37UFPGDSSMEV', 1))
# ('Software', ('A2I0ZWBVR0575O', 1))
# ('Software', ('A1EIVBXG3RD150', 1))
# ('Software', ('A36T3O4TIC1YDQ', 1))
# ('Software', ('A1T6PXM2M3N84A', 1))
# ('Software', ('A1F8RIBFWRYM3Y', 1))
# Sports
# ('Sports', ('A18ZVYTEDAOF9A', 1))
# ('Sports', ('AL62LOJKDES3M', 1))
# ('Sports', ('A3O8EZOX2P399L', 1))
# ('Sports', ('A2RHSQZ7MAKKCO', 1))
# ('Sports', ('A1W180Y9O1FALI', 1))
# Toy
# ('Toy', ('A1SB7SB31ETYZH', 2))
# ('Toy', ('AH4M07U4YC695', 2))
# ('Toy', ('ATVPDKIKX0DER', 2))
# ('Toy', ('A1OSHA4U8RABFY', 1))
# ('Toy', ('AXNOIMARQCT3M', 1))
# ('Toy', ('A1ITRIM68VLZG3', 1))
# ('Toy', ('A1QW8PHDJBH4IC', 1))
# ('Toy', ('A1LEF9EM2DFDP2', 1))
# ('Toy', ('AU8PR9XJ17CCB', 1))
# ('Toy', ('A1K9DVRKH6TZ1L', 1))
# ('Toy', ('A3UN6WX5RRO2AG', 1))
# Video
# ('Video', ('ATVPDKIKX0DER', 72581))
# ('Video', ('A3UN6WX5RRO2AG', 15814))
# ('Video', ('A2NJO6YE954DBH', 1775))
# ('Video', ('AU8552YCOO5QX', 1205))
# ('Video', ('A3P1A63Q8L32C5', 737))
# ('Video', ('A20EEWWSFMZ1PN', 720))
# ('Video', ('A16CZRQL23NOIW', 668))
# ('Video', ('A3LZGLA88K0LA0', 614))
# ('Video', ('A2QRB6L1MCJ53G', 606))
# ('Video', ('A152C8GYY25HAH', 583))
# ('Video', ('A9Q28YTLYREO7', 579))
# Video Games
# ('Video Games', ('A3C811U31YG6FS', 1))
# ('Video Games', ('A226EDS7WDF7S1', 1))
# ('Video Games', ('A1M4NJYP0WNL8Q', 1))

# %% [markdown]
# #Gerando Link Para Visualizar Histórico dos Jobs do Spark

# %%
# !gcloud dataproc clusters describe matheus-dantas-3105 --region=us-central1 > info.txt

# %%
print('Link:')
# !grep Spark info.txt
# Out:
# Link:
#       Spark History Server: https://earehkphpjgjpmdw4yx3rp5nnm-dot-us-central1.dataproc.googleusercontent.com/sparkhistory/

# %% [markdown]
# #Excluir o cluster

# %%
# !gcloud beta dataproc clusters delete matheus-dantas-3105
# Out:
# The cluster 'matheus-dantas-3105' and all attached disks will be
# deleted.
#
# Do you want to continue (Y/n)?  y
#
# Waiting on operation [projects/matheus-dantas-3105/regions/us-central1/operations/486df6d9-98a7-372b-98c3-6e4360e725e1].
# Deleted [https://dataproc.googleapis.com/v1beta2/projects/matheus-dantas-3105/regions/us-central1/clusters/matheus-dantas-3105].

# %% [markdown]
# #Excluir o bucket

# %%
# !gsutil rm -r gs://ufam-bucket-1-matheus-dantas
# Out:
# Removing gs://ufam-bucket-1-matheus-dantas/amazon-meta.txt#1621217474764153...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/cluster.properties#1621217500673093...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/18d006c58b7c4230a9b2f2f2df6316df/driveroutput.000000000#1621218238800248...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/18d006c58b7c4230a9b2f2f2df6316df/driveroutput.000000001#1621218238886521...
# / [4 objects]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m rm ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/18d006c58b7c4230a9b2f2f2df6316df/staging/e.py#1621218144446815...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/3935f92e2ea048d6b31cec186e5462e5/driveroutput.000000000#1621218003986161...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/3935f92e2ea048d6b31cec186e5462e5/driveroutput.000000001#1621218004244484...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/3935f92e2ea048d6b31cec186e5462e5/staging/c.py#1621217951151176...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/5022609da8434c3fb72fb00ef477a73e/driveroutput.000000000#1621217882369279...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/5022609da8434c3fb72fb00ef477a73e/driveroutput.000000001#1621217883119648...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/5022609da8434c3fb72fb00ef477a73e/staging/a.py#1621217864487171...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/75732fb1465b400699c00dafa9c5eced/driveroutput.000000000#1621218138078022...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/75732fb1465b400699c00dafa9c5eced/driveroutput.000000001#1621218138618806...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/75732fb1465b400699c00dafa9c5eced/staging/d.py#1621218009703393...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/9045808067e3426eb8bf70e884a0ead3/driveroutput.000000000#1621218349144249...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/9045808067e3426eb8bf70e884a0ead3/driveroutput.000000001#1621218349631812...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/9045808067e3426eb8bf70e884a0ead3/staging/f.py#1621218244704121...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/941720c0a16743be93a376e8524af32d/driveroutput.000000000#1621217854486788...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/941720c0a16743be93a376e8524af32d/driveroutput.000000001#1621217854535439...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/941720c0a16743be93a376e8524af32d/staging/wordcount.py#1621217808744163...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/b7881b5138724a8a87fe72097a37036c/driveroutput.000000000#1621218491147359...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs/b7881b5138724a8a87fe72097a37036c/driveroutput.000000001#1621218491184777...
# Removing gs://ufam-bucket-1-matheus-dantas/google-cloud-dataproc-metainfo/202243a9-e77a-4c97-b076-e62fb8bfad6b/jobs